# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaggau/IR_LDC/blob/main/model/ECTHR/ecthr_run_frozen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://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@github.com/danielsaggau/IR_LDC.git

# %%
# %cd IR_LDC
# Out:
# /content/IR_LDC

# %%
# !pip install -r requirements.txt

# %%
# !pip install wandb
# !wandb login fd6f7deb3126d40be9abf77ee753bf45f00e2a9a
# %env WANDB_PROJECT=IR_LDC

# %%
# !python /content/IR_LDC/model/Longformer/Longformer/convert_bert_to_longformer.py
# Out:
# Some weights of the model checkpoint at nlpaueb/legal-bert-small-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading: 100% 694/694 [00:00<00:00, 712kB/s]
# Longformer model is ready to run!

# %%
# !python /content/IR_LDC/model/ECTHR/ecthr_bregman_classification.py \
    --output_dir logs/output_1 \
    --model_name '/content/IR_LDC/models/legal-longformer' \
    --load_best_model_at_end \
    --model_type 'mean' \
    --overwrite_output_dir \
    --evaluation_strategy epoch \
    --save_strategy epoch \
    --learning_rate 1e-4 \
    --per_device_train_batch_size 6 \
    --per_device_eval_batch_size 6 \
    --weight_decay 0.01 \
    --push_to_hub \
    --fp16 \
    --num_train_epochs 20 \
    --gradient_accumulation_steps 1 \
    --metric_for_best_model "micro-f1" \
    --greater_is_better 1 \
    --freezing \
    --report_to 'wandb' \
    --model_type 'ecthr_breg_frozen_mean'
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#  74% 123/167 [00:28<00:10,  4.34it/s]
#  74% 124/167 [00:28<00:09,  4.33it/s]
#  75% 125/167 [00:28<00:09,  4.34it/s]
#  75% 126/167 [00:28<00:09,  4.36it/s]
#  76% 127/167 [00:29<00:09,  4.37it/s]
#  77% 128/167 [00:29<00:09,  4.33it/s]
#  77% 129/167 [00:29<00:08,  4.34it/s]
#  78% 130/167 [00:29<00:08,  4.31it/s]
#  78% 131/167 [00:29<00:08,  4.34it/s]
#  79% 132/167 [00:30<00:07,  4.38it/s]
#  80% 133/167 [00:30<00:07,  4.37it/s]
#  80% 134/167 [00:30<00:07,  4.36it/s]
#  81% 135/167 [00:30<00:07,  4.37it/s]
#  81% 136/167 [00:31<00:07,  4.36it/s]
#  82% 137/167 [00:31<00:06,  4.35it/s]
#  83% 138/167 [00:31<00:06,  4.35it/s]
#  83% 139/167 [00:31<00:06,  4.36it/s]
#  84% 140/167 [00:31<00:06,  4.38it/s]
#  84% 141/167 [00:32<00:05,  4.37it/s]
#  85% 142/167 [00:32<00:05,  4.37it/s]
#  86% 143/167 [00:32<00:05,  4.37it/s]
#  86% 144/167 [00:32<00:05,  4.37it/s]
#  87% 145/167 [00:33<00:05,  4.35it/s]
# ...
