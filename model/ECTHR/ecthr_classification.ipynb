# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaggau/IR_LDC/blob/main/model/ECTHR/ECTHR_SIMCSE_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Load packages

# %%
# !git clone https://github.com/danielsaggau/IR_LDC.git

# %%
# %cd IR_LDC

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # load Datasets

# %%
from datasets import load_dataset
dataset = load_dataset("lex_glue", "ecthr_b")
# Out:
# Downloading builder script:   0%|          | 0.00/23.3k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/32.4k [00:00<?, ?B/s]
# Downloading and preparing dataset lex_glue/ecthr_b to /root/.cache/huggingface/datasets/lex_glue/ecthr_b/1.0.0/8a66420941bf6e77a7ddd4da4d3bfb7ba88ef48c1d55302a568ac650a095ca3a...
# Downloading data:   0%|          | 0.00/32.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Dataset lex_glue downloaded and prepared to /root/.cache/huggingface/datasets/lex_glue/ecthr_b/1.0.0/8a66420941bf6e77a7ddd4da4d3bfb7ba88ef48c1d55302a568ac650a095ca3a. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # Connect to Huggingface
# Alternativ 1 via pop up window and entering access token

# %%
#from huggingface_hub import notebook_login
#notebook_login()
#access code:

# %% [markdown]
# Alternativ 2 using the direct command

# %%
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('XXXX')"

# %% [markdown]
# # Set labels
# We set the labels to 10 and also pass this argument to the ```AutoModelForSequenceClassification``` function

# %%
label_list = list(range(10))
num_labels = len(label_list)

# %% [markdown]
# Instantiating the model and the tokenizer from our pre-trained model. This model was pre-trained similarly to `SIMCSE`. Further are using the ``use_fast=True`` specification of the tokenizer.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("danielsaggau/simcse_longformer_ecthr_b", use_auth_token=True, use_fast=True)
# tokenizer =  AutoTokenizer.from_pretrained("allenai/longformer-base-4096")
model = AutoModelForSequenceClassification.from_pretrained("danielsaggau/simcse_longformer_ecthr_b", num_labels=10, problem_type='multi_label_classification')
# model = AutoModelForSequenceClassification.from_pretrained("allenai/longformer-base-4096", num_labels=10)
# Out:
# Downloading:   0%|          | 0.00/453 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/222k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/702k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at danielsaggau/simcse_longformer_ecthr_b and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Data Collator
# Set colaltor to ``pad_to_multiple`` of 8 for efficiency (FP16)

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer, pad_to_multiple_of=8) # fp16

# %% [markdown]
# Here we add global attention mask for the longformer as our attention mechanism is twofold

# %%
import numpy as np

def preprocess_function(examples):
        # Tokenize the texts
        cases = []
        padding = "max_length"
        max_seq_length=4096
        for case in examples['text']:
            cases.append(f' {tokenizer.sep_token} '.join([fact for fact in case]))
        batch = tokenizer(cases, padding=padding, max_length=4096, truncation=True)
        # use global attention on CLS token
        global_attention_mask = np.zeros((len(cases),max_seq_length), dtype=np.int32)
        global_attention_mask[:, 0] = 1
        batch['global_attention_mask'] = list(global_attention_mask)
        batch["labels"] = [[1.0 if label in labels else 0.0 for label in label_list] for labels in examples["labels"]]
        return batch

# %%
tokenized_data = dataset.map(preprocess_function, batched=True,remove_columns=['text'])
# Out:
#   0%|          | 0/9 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
# cast label IDs to floats
import torch 
tokenized_data.set_format("torch")
tokenized_data = (tokenized_data
          .map(lambda x : {"float_labels": x["labels"].to(torch.float)}, remove_columns=["labels"])
          .rename_column("float_labels", "labels"))
# Out:
#   0%|          | 0/9000 [00:00<?, ?ex/s]
#   0%|          | 0/1000 [00:00<?, ?ex/s]
#   0%|          | 0/1000 [00:00<?, ?ex/s]

# %%
from transformers import EvalPrediction
from scipy.special import expit
from sklearn.metrics import f1_score

def compute_metrics(p: EvalPrediction):
        # Fix gold labels
        y_true = np.zeros((p.label_ids.shape[0], p.label_ids.shape[1] + 1), dtype=np.int32)
        y_true[:, :-1] = p.label_ids
        y_true[:, -1] = (np.sum(p.label_ids, axis=1) == 0).astype('int32')
        # Fix predictions
        logits = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
        preds = (expit(logits) > 0.5).astype('int32')
        y_pred = np.zeros((p.label_ids.shape[0], p.label_ids.shape[1] + 1), dtype=np.int32)
        y_pred[:, :-1] = preds
        y_pred[:, -1] = (np.sum(preds, axis=1) == 0).astype('int32')
        # Compute scores
        macro_f1 = f1_score(y_true=y_true, y_pred=y_pred, average='macro', zero_division=0)
        micro_f1 = f1_score(y_true=y_true, y_pred=y_pred, average='micro', zero_division=0)
        return {'macro-f1': macro_f1, 'micro-f1': micro_f1}

# %% [markdown]
# # Specify the training arguments
# Here we use a respective batch size of 6 as we are using longformer. Further we use a learning rate of 3e-5 as done by chalkidis et al in lexglue.
# Further we save results by epoch. The metric for the best model is our micro f1. One needs to ensure that the highest score is best so we use greater is better and we load the best model at the end.
# For more pronounced performance increase number of epochs.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="/ecthr_b_classsification",
    learning_rate=3e-5,
    per_device_train_batch_size=6,
    per_device_eval_batch_size=6,
    num_train_epochs=20,
    weight_decay=0.01,
    fp16=True,
    eval_steps=500,
    save_strategy="steps",
    evaluation_strategy="steps",
    logging_steps=500,
    logging_dir='./logs',  
    logging_first_step = True,
    logging_strategy = 'steps',
    #push_to_hub=True,
    metric_for_best_model="micro-f1",
    greater_is_better=True,
    load_best_model_at_end = True
)

# %% [markdown]
# Specifying costum trainer with multiple label classification loss

# %%
from torch import cuda
cuda.empty_cache()

# %%
from transformers import EarlyStoppingCallback
from transformers import Trainer
hist =Trainer(
    model=model,
    compute_metrics=compute_metrics,
    args=training_args,
    eval_dataset=tokenized_data['validation'],
    train_dataset=tokenized_data['train'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=5)])
hist.train()
# Out:
# Using cuda_amp half precision backend
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 9000
#   Num Epochs = 20
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 1
#   Total optimization steps = 30000
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='6369' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6369/30000 1:35:04 < 5:52:53, 1.12 it/s, Epoch 4.25/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Macro-f1</th>
#       <th>Micro-f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.258600</td>
#       <td>0.223160</td>
#       <td>0.416768</td>
#       <td>0.625095</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.170000</td>
#       <td>0.188160</td>
#       <td>0.511461</td>
#       <td>0.719033</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.159000</td>
#       <td>0.180757</td>
#       <td>0.553979</td>
#       <td>0.731597</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.132900</td>
#       <td>0.172609</td>
#       <td>0.549759</td>
#       <td>0.737791</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.130700</td>
#       <td>0.165109</td>
#       <td>0.710960</td>
#       <td>0.784973</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.130400</td>
#       <td>0.153277</td>
#       <td>0.658080</td>
#       <td>0.781669</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.105000</td>
#       <td>0.165728</td>
#       <td>0.703103</td>
#       <td>0.764331</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.110000</td>
#       <td>0.152246</td>
#       <td>0.688728</td>
#       <td>0.799706</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.106200</td>
#       <td>0.153134</td>
#       <td>0.696974</td>
#       <td>0.792913</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.083700</td>
#       <td>0.155447</td>
#       <td>0.735737</td>
#       <td>0.800147</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.088800</td>
#       <td>0.158035</td>
#       <td>0.695365</td>
#       <td>0.792260</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.087600</td>
#       <td>0.166144</td>
#       <td>0.709400</td>
#       <td>0.787367</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-500
# Configuration saved in /ecthr_b_classsification/checkpoint-500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-1000
# Configuration saved in /ecthr_b_classsification/checkpoint-1000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-1500
# Configuration saved in /ecthr_b_classsification/checkpoint-1500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-1500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-2000
# Configuration saved in /ecthr_b_classsification/checkpoint-2000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-2500
# Configuration saved in /ecthr_b_classsification/checkpoint-2500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-2500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-3000
# Configuration saved in /ecthr_b_classsification/checkpoint-3000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-3000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-3500
# Configuration saved in /ecthr_b_classsification/checkpoint-3500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-4000
# Configuration saved in /ecthr_b_classsification/checkpoint-4000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-4000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-4500
# Configuration saved in /ecthr_b_classsification/checkpoint-4500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-5000
# Configuration saved in /ecthr_b_classsification/checkpoint-5000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-5000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-5500
# Configuration saved in /ecthr_b_classsification/checkpoint-5500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-5500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-6000
# Configuration saved in /ecthr_b_classsification/checkpoint-6000/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-6000/special_tokens_map.json
#     <div>
#
#       <progress value='6500' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6500/30000 1:37:33 < 5:52:47, 1.11 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Macro-f1</th>
#       <th>Micro-f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.258600</td>
#       <td>0.223160</td>
#       <td>0.416768</td>
#       <td>0.625095</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.170000</td>
#       <td>0.188160</td>
#       <td>0.511461</td>
#       <td>0.719033</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.159000</td>
#       <td>0.180757</td>
#       <td>0.553979</td>
#       <td>0.731597</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.132900</td>
#       <td>0.172609</td>
#       <td>0.549759</td>
#       <td>0.737791</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.130700</td>
#       <td>0.165109</td>
#       <td>0.710960</td>
#       <td>0.784973</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.130400</td>
#       <td>0.153277</td>
#       <td>0.658080</td>
#       <td>0.781669</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.105000</td>
#       <td>0.165728</td>
#       <td>0.703103</td>
#       <td>0.764331</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.110000</td>
#       <td>0.152246</td>
#       <td>0.688728</td>
#       <td>0.799706</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.106200</td>
#       <td>0.153134</td>
#       <td>0.696974</td>
#       <td>0.792913</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.083700</td>
#       <td>0.155447</td>
#       <td>0.735737</td>
#       <td>0.800147</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.088800</td>
#       <td>0.158035</td>
#       <td>0.695365</td>
#       <td>0.792260</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.087600</td>
#       <td>0.166144</td>
#       <td>0.709400</td>
#       <td>0.787367</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.066600</td>
#       <td>0.163441</td>
#       <td>0.750758</td>
#       <td>0.796123</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /ecthr_b_classsification/checkpoint-6500
# Configuration saved in /ecthr_b_classsification/checkpoint-6500/config.json
# Model weights saved in /ecthr_b_classsification/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /ecthr_b_classsification/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /ecthr_b_classsification/checkpoint-6500/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /ecthr_b_classsification/checkpoint-5000 (score: 0.8001474926253687).
# TrainOutput(global_step=6500, training_loss=0.12541871590797718, metrics={'train_runtime': 5856.5242, 'train_samples_per_second': 30.735, 'train_steps_per_second': 5.122, 'total_flos': 2.2917757943808e+16, 'train_loss': 0.12541871590797718, 'epoch': 4.33})

# %%
hist.evaluate(eval_dataset=tokenized_data['validation'])
# Out:
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
#     <div>
#
#       <progress value='167' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [167/167 00:39]
#     </div>
# {'eval_loss': 0.15544691681861877,
#  'eval_macro-f1': 0.7357372124149993,
#  'eval_micro-f1': 0.8001474926253687,
#  'eval_runtime': 39.8864,
#  'eval_samples_per_second': 25.071,
#  'eval_steps_per_second': 4.187,
#  'epoch': 4.33}

# %% [markdown]
# # Frozen layer continued training

# %%
for name, param in model.named_parameters():
     if name.startswith("longformer."): # choose whatever you like here
        param.requires_grad = False

# %%
model

# %%
for name, param in model.named_parameters():
     print(name, param.requires_grad)

# %%
from transformers import EarlyStoppingCallback
from transformers import Trainer
froz =Trainer(
    model=model,
    compute_metrics=compute_metrics,
    args=training_args,
    eval_dataset=tokenized_data['validation'],
    train_dataset=tokenized_data['train'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=5)])
froz.train()

# %%
hist.evaluate(eval_dataset=tokenized_data['validation'])
# Out:
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
#     <div>
#
#       <progress value='167' max='167' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [167/167 00:37]
#     </div>
# {'eval_loss': 0.15733712911605835,
#  'eval_macro-f1': 0.7414001299967447,
#  'eval_micro-f1': 0.8,
#  'eval_runtime': 38.2757,
#  'eval_samples_per_second': 26.126,
#  'eval_steps_per_second': 4.363,
#  'epoch': 2.5}

# %% [markdown]
# # ECTHR Task A

# %%
dataset = load_dataset("lex_glue", "ecthr_a")

# %%
tokenizer = AutoTokenizer.from_pretrained("danielsaggau/simcse_longformer_ecthr_b", use_auth_token=True, use_fast=True)
# tokenizer =  AutoTokenizer.from_pretrained("allenai/longformer-base-4096")
model = AutoModelForSequenceClassification.from_pretrained("danielsaggau/simcse_longformer_ecthr_b", num_labels=10, problem_type='multi_label_classification')

# %%
for name, param in model.named_parameters():
     if name.startswith("longformer."): # choose whatever you like here
        param.requires_grad = False

# %%
tokenized_data = dataset.map(preprocess_function, batched=True,remove_columns=['text'])

# %%
# cast label IDs to floats
import torch 
tokenized_data.set_format("torch")
tokenized_data = (tokenized_data
          .map(lambda x : {"float_labels": x["labels"].to(torch.float)}, remove_columns=["labels"])
          .rename_column("float_labels", "labels"))
# Out:
#   0%|          | 0/9000 [00:00<?, ?ex/s]
#   0%|          | 0/1000 [00:00<?, ?ex/s]
#   0%|          | 0/1000 [00:00<?, ?ex/s]

# %%
from transformers import EarlyStoppingCallback
from transformers import Trainer
froz_A =Trainer(
    model=model,
    compute_metrics=compute_metrics,
    args=training_args,
    eval_dataset=tokenized_data['validation'],
    train_dataset=tokenized_data['train'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=5)])
froz_A.train()
# Out:
# Using cuda_amp half precision backend
# ***** Running training *****
#   Num examples = 9000
#   Num Epochs = 20
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 1
#   Total optimization steps = 30000
#     <div>
#
#       <progress value='10202' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10202/30000 1:09:36 < 2:15:05, 2.44 it/s, Epoch 6.80/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Macro-f1</th>
#       <th>Micro-f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>250</td>
#       <td>0.399300</td>
#       <td>0.299194</td>
#       <td>0.079324</td>
#       <td>0.282774</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.262600</td>
#       <td>0.279984</td>
#       <td>0.082493</td>
#       <td>0.299776</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.244500</td>
#       <td>0.265523</td>
#       <td>0.083184</td>
#       <td>0.292487</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.225500</td>
#       <td>0.254524</td>
#       <td>0.109528</td>
#       <td>0.318283</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.218900</td>
#       <td>0.246292</td>
#       <td>0.143195</td>
#       <td>0.363313</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.208800</td>
#       <td>0.236498</td>
#       <td>0.183590</td>
#       <td>0.395944</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.200900</td>
#       <td>0.230766</td>
#       <td>0.229706</td>
#       <td>0.441941</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.199100</td>
#       <td>0.227964</td>
#       <td>0.233700</td>
#       <td>0.440781</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.194500</td>
#       <td>0.222225</td>
#       <td>0.251685</td>
#       <td>0.464716</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.190500</td>
#       <td>0.220647</td>
#       <td>0.259803</td>
#       <td>0.476640</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.186300</td>
#       <td>0.217285</td>
#       <td>0.272138</td>
#       <td>0.498299</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.186400</td>
#       <td>0.213130</td>
#       <td>0.277840</td>
#       <td>0.498732</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.183300</td>
#       <td>0.212413</td>
#       <td>0.277604</td>
#       <td>0.499575</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.176800</td>
#       <td>0.209566</td>
#       <td>0.280787</td>
#       <td>0.506168</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.180600</td>
#       <td>0.207814</td>
#       <td>0.285949</td>
#       <td>0.511667</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.178000</td>
#       <td>0.207978</td>
#       <td>0.290449</td>
#       <td>0.518923</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.178000</td>
#       <td>0.204762</td>
#       <td>0.302260</td>
#       <td>0.523129</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.170100</td>
#       <td>0.205466</td>
#       <td>0.309175</td>
#       <td>0.527859</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.170800</td>
#       <td>0.203331</td>
#       <td>0.309329</td>
#       <td>0.523325</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.168800</td>
#       <td>0.199537</td>
#       <td>0.319002</td>
#       <td>0.530405</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.172800</td>
#       <td>0.199238</td>
#       <td>0.319455</td>
#       <td>0.526895</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.164800</td>
#       <td>0.200266</td>
#       <td>0.316234</td>
#       <td>0.528397</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.170500</td>
#       <td>0.200038</td>
#       <td>0.321343</td>
#       <td>0.534786</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.171900</td>
#       <td>0.200302</td>
#       <td>0.323661</td>
#       <td>0.534454</td>
#     </tr>
#     <tr>
#       <td>6250</td>
#       <td>0.165300</td>
#       <td>0.197530</td>
#       <td>0.324045</td>
#       <td>0.529461</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.166500</td>
#       <td>0.196145</td>
#       <td>0.334550</td>
#       <td>0.540244</td>
#     </tr>
#     <tr>
#       <td>6750</td>
#       <td>0.161100</td>
#       <td>0.196563</td>
#       <td>0.335467</td>
#       <td>0.538170</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.163400</td>
#       <td>0.195023</td>
#       <td>0.345670</td>
#       <td>0.546521</td>
#     </tr>
#     <tr>
#       <td>7250</td>
#       <td>0.164100</td>
#       <td>0.196576</td>
#       <td>0.328092</td>
#       <td>0.533895</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.172200</td>
#       <td>0.193486</td>
#       <td>0.363587</td>
#       <td>0.555092</td>
#     </tr>
#     <tr>
#       <td>7750</td>
#       <td>0.164600</td>
#       <td>0.192083</td>
#       <td>0.348187</td>
#       <td>0.543460</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.164000</td>
#       <td>0.191982</td>
#       <td>0.345746</td>
#       <td>0.552245</td>
#     </tr>
#     <tr>
#       <td>8250</td>
#       <td>0.161900</td>
#       <td>0.192005</td>
#       <td>0.359392</td>
#       <td>0.556159</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.164500</td>
#       <td>0.190224</td>
#       <td>0.364885</td>
#       <td>0.555975</td>
#     </tr>
#     <tr>
#       <td>8750</td>
#       <td>0.155600</td>
#       <td>0.193466</td>
#       <td>0.362477</td>
#       <td>0.553475</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.166100</td>
#       <td>0.190294</td>
#       <td>0.357215</td>
#       <td>0.550505</td>
#     </tr>
#     <tr>
#       <td>9250</td>
#       <td>0.164700</td>
#       <td>0.188468</td>
#       <td>0.366808</td>
#       <td>0.554850</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.157800</td>
#       <td>0.189175</td>
#       <td>0.363212</td>
#       <td>0.558996</td>
#     </tr>
#     <tr>
#       <td>9750</td>
#       <td>0.160500</td>
#       <td>0.190842</td>
#       <td>0.366288</td>
#       <td>0.556065</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.155400</td>
#       <td>0.188722</td>
#       <td>0.365224</td>
#       <td>0.549599</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-1000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-1000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-1000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-1500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-1500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-1500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-2000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-2000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-2000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-2500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-2500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-2500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-3000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-3000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-3000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-3500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-3500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-3500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-4000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-4000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-4000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-4500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-4500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-4500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-5000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-5000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-5000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-5500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-5500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-5500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-6000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-6000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-6000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-6500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-6500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-6500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-7000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-7000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-7000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-7500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-7500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-7500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-8000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-8000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-8000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-8500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-8500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-8500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-9000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-9000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-9000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-9500
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-9500/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-9500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 6
# Saving model checkpoint to /slbert_ecthr_b_classsification/checkpoint-10000
# Configuration saved in /slbert_ecthr_b_classsification/checkpoint-10000/config.json
# Model weights saved in /slbert_ecthr_b_classsification/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /slbert_ecthr_b_classsification/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /slbert_ecthr_b_classsification/checkpoint-10000/special_tokens_map.json
