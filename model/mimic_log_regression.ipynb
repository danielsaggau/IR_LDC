# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaggau/IR_LDC/blob/main/mimic_log_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentence_transformers

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score
from sklearn.linear_model import LogisticRegression
from sentence_transformers import SentenceTransformer, InputExample, losses, models, datasets, evaluation
from torch.utils.data import DataLoader

from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np

import torch
import random
import torch

def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)

# %%
# !git clone https://github.com/danielsaggau/IR_LDC.git

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
# !unzip /content/drive/MyDrive/mimic.jsonl.zip -d content
#with open('content/mimic.jsonl') as f:
#    data = [json.loads(line) for line in f]
# Out:
# Archive:  /content/drive/MyDrive/mimic.jsonl.zip
#   inflating: content/mimic.jsonl
#   inflating: content/__MACOSX/._mimic.jsonl

# %%
import shutil
# !pip install datasets
from datasets import load_dataset
shutil.move("/content/content/mimic.jsonl", "/content/IR_LDC/model/MIMIC")
dataset = load_dataset("/content/IR_LDC/model/MIMIC/mimic-dataset.py")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('XXXX')"
#tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/bregman_mimic_FT", use_auth_token=True, use_fast=True)

# %%
#model = AutoModelForSequenceClassification.from_pretrained("/content/drive/MyDrive/bregman_mimic_FT", use_auth_token=True,num_labels=19, problem_type='multi_label_classification')

# %%
train_df = dataset['train']
eval_df = dataset['validation']
text_col=train_df['text'] 
category_col=train_df['labels']
x_eval = eval_df['text']
y_eval = eval_df['labels']

# %%
model = SentenceTransformer("/content/drive/MyDrive/bregman_mimic_FT", use_auth_token=True)
model

# %%
X_train_noFT = model.encode(text_col)
X_eval_noFT = model.encode(x_eval)

# %%
sgd =  LogisticRegression(max_iter=10000,multi_class='multinomial', solver='lbfgs')

# %%
from sklearn.preprocessing import MultiLabelBinarizer
MultiLabelBinarizer()
# Out:
# MultiLabelBinarizer()

# %%
category_col = MultiLabelBinarizer().fit_transform(category_col)
y_eval = MultiLabelBinarizer().fit_transform(y_eval)

# %%
sgd.fit(X_train_noFT, category_col.argmax(axis=1)) # https://stackoverflow.com/questions/73970907/python-code-error-valueerror-y-should-be-a-1d-array-got-an-array-of-shape-56
# Out:
# LogisticRegression(max_iter=10000, multi_class='multinomial')

# %%
y_pred_eval_sgd = sgd.predict(X_eval_noFT)

# %%
print('f1 micro Fit', f1_score(y_eval.argmax(axis=1), y_pred_eval_sgd, average="micro"))
print('f1 macro Fit', f1_score(y_eval.argmax(axis=1), y_pred_eval_sgd, average="macro"))
# Out:
# f1 micro Fit 0.5696
# f1 macro Fit 0.21242315942813408

# %%
import gc
torch.cuda.empty_cache()
obj = None
gc.collect()
# Out:
# 0

# %%
with torch.no_grad():
    torch.cuda.empty_cache()

# %%
del model

# %%
model_lf = SentenceTransformer("yikuan8/Clinical-Longformer", use_auth_token=True)

# %%
X_train_noFT = model_lf.encode(text_col, show_progress_bar=True)
X_eval_noFT = model_lf.encode(x_eval, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/938 [00:00<?, ?it/s]
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]

# %%
sgd =  LogisticRegression(max_iter=10000,multi_class='multinomial', solver='lbfgs')
sgd.fit(X_train_noFT, category_col.argmax(axis=1)) # https://stackoverflow.com/questions/73970907/python-code-error-valueerror-y-should-be-a-1d-array-got-an-array-of-shape-56
# Out:
# LogisticRegression(max_iter=10000, multi_class='multinomial')

# %%
y_pred_eval_sgd = sgd.predict(X_eval_noFT)

# %%
print('f1 micro Fit', f1_score(y_eval.argmax(axis=1), y_pred_eval_sgd, average="micro"))
print('f1 macro Fit', f1_score(y_eval.argmax(axis=1), y_pred_eval_sgd, average="macro"))

# %%
import sentence_transformers
from transformers import AutoModel
model_simcse = AutoModel.from_pretrained("danielsaggau/MIMIC_SIMCSE", use_auth_token=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9ebb705750a6> in <module>
#       2 from transformers import AutoModel
#       3 model_simcse = AutoModel.from_pretrained("danielsaggau/MIMIC_SIMCSE", use_auth_token=True)
# ----> 4 model_simcse = SentenceTransformer(model_simcse)
#       5 X_train_noFT = model_simcse.encode(text_col, show_progress_bar=True)
#       6 X_eval_noFT = model_simce.encode(x_eval, show_progress_bar=True)
#
# /usr/local/lib/python3.8/dist-packages/sentence_transformers/SentenceTransformer.py in __init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      69             basic_transformer_models = ['albert-base-v1', 'albert-base-v2', 'albert-large-v1', 'albert-large-v2', 'albert-xlarge-v1', 'albert-xlarge-v2', 'albert-xxlarge-v1', 'albert-xxlarge-v2', 'bert-base-cased-finetuned-mrpc', 'bert-base-cased', 'bert-base-chinese', 'bert-base-german-cased', 'bert-base-german-dbmdz-cased', 'bert-base-german-dbmdz-uncased', 'bert-base-multilingual-cased', 'bert-base-multilingual-uncased', 'bert-base-uncased', 'bert-large-cased-whole-word-masking-finetuned-squad', 'bert-large-cased-whole-word-masking', 'bert-large-cased', 'bert-large-uncased-whole-word-masking-finetuned-squad', 'bert-large-uncased-whole-word-masking', 'bert-large-uncased', 'camembert-base', 'ctrl', 'distilbert-base-cased-distilled-squad', 'distilbert-base-cased', 'distilbert-base-german-cased', 'distilbert-base-m...
#      70
# ---> 71             if os.path.exists(model_name_or_path):
#      72                 #Load from path
#      73                 model_path = model_name_or_path
#
# /usr/lib/python3.8/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not BertModel

# %%
model_simcse = SentenceTransformer(model_simcse)
X_train_noFT = model_simcse.encode(text_col, show_progress_bar=True)
X_eval_noFT = model_simce.encode(x_eval, show_progress_bar=True)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("danielsaggau/MIMIC_SIMCSE")
model = SentenceTransformer("bionlp/bluebert_pubmed_mimic_uncased_L-12_H-768_A-12")
# Out:
# Downloading:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/699 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/449 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-881016ef8d5b> in <module>
#       1 from sentence_transformers import SentenceTransformer
# ----> 2 model = SentenceTransformer("danielsaggau/MIMIC_SIMCSE")
#
# /usr/local/lib/python3.8/dist-packages/sentence_transformers/SentenceTransformer.py in __init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      93
#      94             if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
# ---> 95                 modules = self._load_sbert_model(model_path)
#      96             else:   #Load with AutoModel
#      97                 modules = self._load_auto_model(model_path)
#
# /usr/local/lib/python3.8/dist-packages/sentence_transformers/SentenceTransformer.py in _load_sbert_model(self, model_path)
#     838         for module_config in modules_config:
#     839             module_class = import_from_string(module_config['type'])
# --> 840             module = module_class.load(os.path.join(model_path, module_config['path']))
#     841             modules[module_config['name']] = module
#     842
#
# /usr/local/lib/python3.8/dist-packages/sentence_transformers/models/Transformer.py in load(input_path)
#     133                 break
#     134
# --> 135         with open(sbert_config_path) as fIn:
#     136             config = json.load(fIn)
#     137         return Transformer(model_name_or_path=input_path, **config)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.cache/torch/sentence_transformers/danielsaggau_MIMIC_SIMCSE/sentence_xlnet_config.json'
