# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsaggau/IR_LDC/blob/main/model/SCOTUS/mean_pool_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets
from datasets import load_dataset

# %%
dataset=load_dataset('lex_glue', 'scotus')

# %%
from transformers import AutoTokenizer
#!python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('XXXX')"
tokenizer = AutoTokenizer.from_pretrained('danielsaggau/longformer_simcse_scotus', use_auth_token=True,use_fast=True)

# %%
from transformers import AutoModelForSequenceClassification
model = AutoModelForSequenceClassification.from_pretrained('danielsaggau/longformer_simcse_scotus',use_auth_token=True, num_labels=14)
# Out:
# All model checkpoint weights were used when initializing LongformerForSequenceClassification.
#
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at danielsaggau/longformer_simcse_scotus and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import torch 
from torch import nn

# %%
# Copied from transformers.models.bert.modeling_bert.BertPooler
class CustomLongformerPooler(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.dense = nn.Linear(config.hidden_size, config.hidden_size)
        self.activation = nn.Tanh()

    def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
        # We "pool" the model by simply taking the hidden state corresponding
        # to the first token.
        mean_token_tensor = hidden_states.mean(dim=1)
        pooled_output = self.dense(mean_token_tensor)
        pooled_output = self.activation(pooled_output)
        return pooled_output

# %%
# Use custom pooler with mean-pooling instead of cls-pooling
model.longformer.pooler = CustomLongformerPooler(model.config)

# %%
def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)

# %%
tokenized_data = dataset.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
from datasets import load_metric
import numpy as np

def compute_metrics(eval_pred):
    metric1 = load_metric("f1")
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    micro1 = metric1.compute(predictions=predictions, references=labels, average="micro")["f1"]
    macro1 = metric1.compute(predictions=predictions, references=labels, average="macro")["f1"]
    return { "f1-micro": micro1, "f1-macro": macro1}

# %%
from transformers import DataCollatorWithPadding
data_collator = DataCollatorWithPadding(tokenizer, pad_to_multiple_of=8) # fp16

# %%
# !git clone https://github.com/danielsaggau/IR_LDC.git

# %%
# %cd IR_LDC
# Out:
# /content/IR_LDC

# %%
# !pip install wandb
import wandb
wandb.login()
#fd6f7deb3126d40be9abf77ee753bf45f00e2a9a

# %%
wandb.init(project="IR_LDC")
wandb.init(name="mean_linear")
# Out:
# Finishing last run (ID:qs4iu8l2) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/f1-macro</td><td>▁▄▅▅▅▅▆▆▆▆▇▇▇▇██████▇</td></tr><tr><td>eval/f1-micro</td><td>▁▄▅▅▆▆▇▇▇▇▇██████████</td></tr><tr><td>eval/loss</td><td>█▅▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁▂▃▃▅▅▄▆▄▅▃▄▅▃▄▄▃▄▄▄█</td></tr><tr><td>eval/samples_per_second</td><td>█▇▆▅▄▄▅▃▅▄▅▅▄▆▅▅▆▅▅▅▁</td></tr><tr><td>eval/steps_per_second</td><td>█▇▆▅▄▄▅▃▄▄▅▄▄▆▅▅▆▅▅▅▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train/learning_rate</td><td>███▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▆▄▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/total_flos</td><td>▁</td></tr><tr><td>train/train_loss</td><td>▁</td></tr><tr><td>train/train_runtime</td><td>▁</td></tr><tr><td>train/train_samples_per_second</td><td>▁</td></tr><tr><td>train/train_steps_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/f1-macro</td><td>0.43072</td></tr><tr><td>eval/f1-micro</td><td>0.64214</td></tr><tr><td>eval/loss</td><td>1.1755</td></tr><tr><td>eval/runtime</td><td>64.9289</td></tr><tr><td>eval/samples_per_second</td><td>21.562</td></tr><tr><td>eval/steps_per_second</td><td>3.604</td></tr><tr><td>train/epoch</td><td>20.0</td></tr><tr><td>train/global_step</td><td>16680</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>0.9168</td></tr><tr><td>train/total_flos</td><td>5.938946662154016e+16</td></tr><tr><td>train/train_loss</td><td>1.06014</td></tr><tr><td>train/train_runtime</td><td>6464.0783</td></tr><tr><td>train/train_samples_per_second</td><td>15.47</td></tr><tr><td>train/train_steps_per_second</td><td>2.58</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">mean_linear_long_train</strong>: <a href="https://wandb.ai/danielsaggau/IR_LDC/runs/qs4iu8l2" target="_blank">https://wandb.ai/danielsaggau/IR_LDC/runs/qs4iu8l2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221117_111341-qs4iu8l2/logs</code>
# Successfully finished last run (ID:qs4iu8l2). Initializing new run:<br/>
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/IR_LDC/wandb/run-20221117_134716-2xn9rftu</code>
# Syncing run <strong><a href="https://wandb.ai/danielsaggau/IR_LDC/runs/2xn9rftu" target="_blank">celestial-meadow-9</a></strong> to <a href="https://wandb.ai/danielsaggau/IR_LDC" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Finishing last run (ID:2xn9rftu) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.104134…
# Synced <strong style="color:#cdcd00">celestial-meadow-9</strong>: <a href="https://wandb.ai/danielsaggau/IR_LDC/runs/2xn9rftu" target="_blank">https://wandb.ai/danielsaggau/IR_LDC/runs/2xn9rftu</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221117_134716-2xn9rftu/logs</code>
# Successfully finished last run (ID:2xn9rftu). Initializing new run:<br/>
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/IR_LDC/wandb/run-20221117_134731-3kmiccir</code>
# Syncing run <strong><a href="https://wandb.ai/danielsaggau/IR_LDC/runs/3kmiccir" target="_blank">mean_linear</a></strong> to <a href="https://wandb.ai/danielsaggau/IR_LDC" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/danielsaggau/IR_LDC/runs/3kmiccir?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    output_dir="/scotus_mean",
    learning_rate=3e-5,
    per_device_train_batch_size=6,
    per_device_eval_batch_size=6,
    num_train_epochs=10,
    weight_decay=0.01,
    save_strategy="epoch",
    evaluation_strategy="epoch",
    push_to_hub=True,
    report_to="wandb",
    fp16=True,
    run_name="mean",
    metric_for_best_model="f1-micro",
    greater_is_better=True,
    load_best_model_at_end = True
)
# Out:
# PyTorch: setting up devices

# %%
from transformers import Trainer, EarlyStoppingCallback
import torch
trainer = Trainer(
    model=model,
    compute_metrics=compute_metrics,
    args=training_args,
    eval_dataset=tokenized_data['test'],
    train_dataset=tokenized_data["train"],
    tokenizer=tokenizer,
    data_collator=data_collator,    
    callbacks = [EarlyStoppingCallback(early_stopping_patience=10)])
trainer.train()
# Out:
# /scotus_mean is already a clone of https://huggingface.co/danielsaggau/scotus_mean. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/scotus_mean is already a clone of https://huggingface.co/danielsaggau/scotus_mean. Make sure you pull the latest changes with `repo.git_pull()`.
# Using cuda_amp half precision backend
# The following columns in the training set don't have a corresponding argument in `LongformerForSequenceClassification.forward` and have been ignored: text. If text are not expected by `LongformerForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 5000
#   Num Epochs = 10
#   Instantaneous batch size per device = 6
#   Total train batch size (w. parallel, distributed & accumulation) = 6
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8340
#   Number of trainable parameters = 41902094
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Initializing global attention on CLS token...
#     <div>
#
#       <progress value='8340' max='8340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8340/8340 2:13:04, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1-micro</th>
#       <th>F1-macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.925200</td>
#       <td>0.950030</td>
#       <td>0.715000</td>
#       <td>0.547118</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.607800</td>
#       <td>1.049444</td>
#       <td>0.732857</td>
#       <td>0.621909</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.463700</td>
#       <td>1.040940</td>
#       <td>0.754286</td>
#       <td>0.672185</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.320900</td>
#       <td>1.224971</td>
#       <td>0.760714</td>
#       <td>0.684528</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.195600</td>
#       <td>1.495215</td>
#       <td>0.753571</td>
#       <td>0.664774</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.144800</td>
#       <td>1.558114</td>
#       <td>0.759286</td>
#       <td>0.671938</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.077500</td>
#       <td>1.592752</td>
#       <td>0.763571</td>
#       <td>0.682401</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.063200</td>
#       <td>1.627468</td>
#       <td>0.768571</td>
#       <td>0.684947</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.039000</td>
#       <td>1.714876</td>
#       <td>0.762143</td>
#       <td>0.683931</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.021500</td>
#       <td>1.705329</td>
#       <td>0.762857</td>
#       <td>0.683185</td>
#     </tr>
#   </tbody>
# </table><p>
# Streaming output truncated to the last 5000 lines.
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Input ids are automatically padded from 2032 to 2048 to be a multiple of `config.attention_window`: 128
# The following columns in the evaluation set don't have a corresponding argument in `LongformerForSequenceClassification.forward` and have been ignored: text. If text are not expected by `LongformerForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1400
#   Batch size = 6
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Saving model checkpoint to /scotus_mean/checkpoint-5004
# Configuration saved in /scotus_mean/checkpoint-5004/config.json
# Model weights saved in /scotus_mean/checkpoint-5004/pytorch_model.bin
# tokenizer config file saved in /scotus_mean/checkpoint-5004/tokenizer_config.json
# Special tokens file saved in /scotus_mean/checkpoint-5004/special_tokens_map.json
# tokenizer config file saved in /scotus_mean/tokenizer_config.json
# Special tokens file saved in /scotus_mean/special_tokens_map.json
# Initializing global attention on CLS token...
# Input ids are automatically padded from 3928 to 3968 to be a multiple of `config.attention_window`: 128
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Input ids are automatically padded from 3216 to 3328 to be a multiple of `config.attention_window`: 128
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# ...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Input ids are automatically padded from 2712 to 2816 to be a multiple of `config.attention_window`: 128
# The following columns in the evaluation set don't have a corresponding argument in `LongformerForSequenceClassification.forward` and have been ignored: text. If text are not expected by `LongformerForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1400
#   Batch size = 6
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Saving model checkpoint to /scotus_mean/checkpoint-8340
# Configuration saved in /scotus_mean/checkpoint-8340/config.json
# Model weights saved in /scotus_mean/checkpoint-8340/pytorch_model.bin
# tokenizer config file saved in /scotus_mean/checkpoint-8340/tokenizer_config.json
# Special tokens file saved in /scotus_mean/checkpoint-8340/special_tokens_map.json
# tokenizer config file saved in /scotus_mean/tokenizer_config.json
# Special tokens file saved in /scotus_mean/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /scotus_mean/checkpoint-6672 (score: 0.7685714285714286).
# TrainOutput(global_step=8340, training_loss=0.2801493309670501, metrics={'train_runtime': 7985.8209, 'train_samples_per_second': 6.261, 'train_steps_per_second': 1.044, 'total_flos': 2.969597381069664e+16, 'train_loss': 0.2801493309670501, 'epoch': 10.0})

# %%
trainer.evaluate(eval_dataset=tokenized_data['validation'])
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `LongformerForSequenceClassification.forward` and have been ignored: text. If text are not expected by `LongformerForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1400
#   Batch size = 6
# Initializing global attention on CLS token...
#     <div>
#
#       <progress value='468' max='234' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [234/234 02:35]
#     </div>
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# Initializing global attention on CLS token...
# {'eval_loss': 1.6274678707122803,
#  'eval_f1-micro': 0.7685714285714286,
#  'eval_f1-macro': 0.684947481074309,
#  'eval_runtime': 64.2551,
#  'eval_samples_per_second': 21.788,
#  'eval_steps_per_second': 3.642,
#  'epoch': 10.0}
